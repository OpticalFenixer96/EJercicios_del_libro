# %% [markdown]
# <a href="https://colab.research.google.com/github/OpticalFenixer96/EJercicios_del_libro/blob/main/Ejercicio%201.12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1.12**

# %% [markdown]
# ![1.12.png](data:image/png;base64,...)

# %% [markdown]
# # **a)**
# Garantizar que la g proporcionada sin ninguna información sobre la función objetivo f y aun asi aproxime bien fuera de la muestra no es posible de garantizar.

# %% [markdown]
# # **b)**
# Enunciar que con alta probabilidad la g producida aproximará bien fuera de la muestra es más factible a traves del uso de un algoritmo de aprendizaje, se puede intentar encontrar una hipótesis g que generalice bien a datos no vistos y asi proporcionar un nivel razonable de confianza en el rendimiento de g.

# %% [markdown]
# # **c)**
#  Si se declara que existe fallo, significara que no pudo encontrar una hipótesis g que aproxime bien fuera de la muestra, pero si se encuentra  una hipótesis g, entonces con alta probabilidad, aproximará bien fuera de la muestra.

# %% [markdown]
# # **RESULTADO**
# De los incisos anteriores el mas realista seria la opcion C, puesto que puede ocurrir que: o bien se llegará a una hipótesis g, o se concluirá que se ha fracasado. Si se proporciona una hipótesis g, entonces con alta probabilidad, aproximará bien fuera de la muestra. Entonces esto tiene una perspectiva mas  ceridica de la situación y a su vez mantiene una alta posibilidad de éxito.
