# %% [markdown]
# <a href="https://colab.research.google.com/github/OpticalFenixer96/EJercicios_del_libro/blob/main/Ejercicio1.11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1.11**

# %% [markdown]
# ![1.11.png](data:image/png;base64,...)

# %% [markdown]
# # **a)**
# Se tiene un conjunto de datos 'D' con 25 ejemplos de entrenamiento, donde la función objetivo se denota como 'f' y mapea desde X a Y, donde X es un espacio de características y Y es el conjunto {-1, +1}. El conjunto de hipótesis consta de dos hipótesis: h1 que corresponde a la función constante y h2 que corresponde a la constante -1.
#
# El algoritmo S selecciona la hipótesis que concuerda más con los datos de entrenamiento y elige deliberadamente la otra hipótesis, como h2 es la constante -1  siempre estará en desacuerdo con la función objetivo f en cualquier punto fuera de 'D' debido a que todos los ejemplos en 'D' tienen Yn = 1. Entonces S no puede producir una hipótesis que tenga un mejor rendimiento que el azar en cualquier punto fuera de 'D'.

# %% [markdown]
# # **b)**
# El algoritmo C elige la hipótesis que está en desacuerdo con la función objetivo f en mayor medida por lo mismo la hipótesis elegida por C será h1 correspondiente a la funciion contante y dado que todos los ejemplos en 'D' tienen Yn = 1, la hipótesis h1 clasificará incorrectamente todos los ejemplos. Por lo mismo la hipótesis producida por C no será mejor que la hipótesis producida por S, que es la constante -1.

# %% [markdown]
# # **c)**
# Primero se asume auna distribución de probabilidad en X, y se cumple P[f(x) = 1] = p. En este caso, p = 0.9, o sea que la probabilidad de que la función objetivo f(x) sea 1 se le asigna la probabilidad de 90%.
#
# Para encontrar la probabilidad de que S produzca una hipótesis mejor que C, se considerara los casos en los que S elige h2 y C elige h1. Dado que h2 es la constante -1, funcionará mejor que h1 (que clasifica incorrectamente todos los ejemplos) si f(x) = -1.
#
# La probabilidad de que S elija h2 se denota como P[f(x) = -1] y es igual a 1 - P[f(x) = 1] = 1 - p = 1 - 0.9 = 0.1.
#
# Por lo tanto, la probabilidad de que S produzca una hipótesis mejor que C es 0.1.

# %% [markdown]
# # **d)**
# Para determinar si existe algún valor de p para el cual sea más probable que C produzca una hipótesis mejor que S, debemos comparar las probabilidades de que S elija h2 y C elija h1.
#
# S elige h2 con una probabilidad de 1 - p, y C elige h1 con una probabilidad de p.
#
# Para que C produzca una hipótesis mejor que S, necesitamos que la probabilidad de que C elija h1 sea mayor que la probabilidad de que S elija h2.
#
# Matemáticamente, queremos que p > 1 - p.
#
# Resolviendo esta desigualdad, obtenemos 2p > 1, lo que se simplifica a p > 0.5.
#
# Por lo tanto, si la probabilidad p es mayor que 0.5, es más probable que C produzca una hipótesis mejor que S.
